# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.get("John Smith")
# Out:
# 2025-11-05 17:44:07,390 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=656, family=2, type=1, proto=0, laddr=('127.0.0.1', 51495), raddr=('127.0.0.1', 50007)>
# 2025-11-05 17:44:07,392 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# [('John Smith', '0721552211')]
# "[('John Smith', '0721552211')]"

# %%
import clientserver # import from our script

client = clientserver.Client()
client.get_all()
# Out:
# 2025-11-05 17:45:49,781 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=612, family=2, type=1, proto=0, laddr=('127.0.0.1', 51514), raddr=('127.0.0.1', 50007)>
# 2025-11-05 17:45:49,783 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# [('John Smith', '0721552211'), ('Caroline Smith', '0721552212'), ('Gordon Harper', '0721552213'), ('Piet Edwards', '0721552214'), ('Frida Frikadelle', '0721552215')]
# "[('John Smith', '0721552211'), ('Caroline Smith', '0721552212'), ('Gordon Harper', '0721552213'), ('Piet Edwards', '0721552214'), ('Frida Frikadelle', '0721552215')]"
