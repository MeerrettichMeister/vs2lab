# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.get("John Smith")
# Out:
# 2025-11-04 14:07:10,062 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=1076, family=2, type=1, proto=0, laddr=('127.0.0.1', 52571), raddr=('127.0.0.1', 50007)>
# 2025-11-04 14:07:10,063 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# [('John Smith', '0721552211')]
# "[('John Smith', '0721552211')]"

# %%
client.get_all()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 client.get_all()
#
# File F:\Uni\HKA\VS2\vs2lab\lab1\clientserver.py:77, in Client.get_all(self)
#      75 def get_all(self):
#      76     query_obj = {"operation":"getAll"}
# ---> 77     self.sock.send(str(query_obj).encode('utf-8'))
#      78     answer = self.sock.recv(1024)
#      79     msg_out = answer.decode("utf-8")
#
# OSError: [WinError 10038] Ein Vorgang bezog sich auf ein Objekt, das kein Socket ist
