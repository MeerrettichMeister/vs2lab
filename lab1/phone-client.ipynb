# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.get("John Smith")

# %%
import clientserver # import from our script

client = clientserver.Client()
client.get_all()

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.get("Hans Müller")
# Out:
# 2025-11-06 12:54:00,155 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=1300, family=2, type=1, proto=0, laddr=('127.0.0.1', 50929), raddr=('127.0.0.1', 50007)>
# 2025-11-06 12:54:00,156 - vs2lab.a1_layers.clientserver.Client - INFO - Sent get request for Hans Müller
# 2025-11-06 12:54:00,157 - vs2lab.a1_layers.clientserver.Client - INFO - Received answer
# 2025-11-06 12:54:00,159 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# []
# '[]'
