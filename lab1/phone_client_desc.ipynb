# %%
from lab1.clientserver import Client

phone_client = Client()
# Out:
# 2025-11-06 14:31:14,945 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=872, family=2, type=1, proto=0, laddr=('127.0.0.1', 56728), raddr=('127.0.0.1', 50007)>

# %% [markdown]
# ### Send request to get a number for a person

# %%
phone_client = Client()
phone_client.get("John Smith")
# Out:
# 2025-11-06 14:31:15,025 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=1556, family=2, type=1, proto=0, laddr=('127.0.0.1', 56729), raddr=('127.0.0.1', 50007)>
# 2025-11-06 14:31:15,025 - vs2lab.a1_layers.clientserver.Client - INFO - Sent get request for John Smith
# 2025-11-06 14:31:15,025 - vs2lab.a1_layers.clientserver.Client - INFO - Received answer
# 2025-11-06 14:31:15,025 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# [('John Smith', '0721552211')]
# "[('John Smith', '0721552211')]"

# %% [markdown]
# ### Send request to get all numbers in the database

# %%
phone_client = Client()
phone_client.get_all()
# Out:
# 2025-11-06 14:31:15,079 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=1516, family=2, type=1, proto=0, laddr=('127.0.0.1', 56730), raddr=('127.0.0.1', 50007)>
# 2025-11-06 14:31:15,081 - vs2lab.a1_layers.clientserver.Client - INFO - Sent getAll request
# 2025-11-06 14:31:15,082 - vs2lab.a1_layers.clientserver.Client - INFO - Received answer
# 2025-11-06 14:31:15,084 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# [('John Smith', '0721552211'), ('Caroline Smith', '0721552212'), ('Gordon Harper', '0721552213'), ('Piet Edwards', '0721552214'), ('Frida Frikadelle', '0721552215')]
# "[('John Smith', '0721552211'), ('Caroline Smith', '0721552212'), ('Gordon Harper', '0721552213'), ('Piet Edwards', '0721552214'), ('Frida Frikadelle', '0721552215')]"

# %% [markdown]
# ### Send request with a not persisted person

# %%
phone_client = Client()
phone_client.get("Hans Müller")
# Out:
# 2025-11-06 14:31:15,188 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=984, family=2, type=1, proto=0, laddr=('127.0.0.1', 56731), raddr=('127.0.0.1', 50007)>
# 2025-11-06 14:31:15,192 - vs2lab.a1_layers.clientserver.Client - INFO - Sent get request for Hans Müller
# 2025-11-06 14:31:15,193 - vs2lab.a1_layers.clientserver.Client - INFO - Received answer
# 2025-11-06 14:31:15,195 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# []
# '[]'
