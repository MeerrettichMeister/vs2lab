# %% [markdown]
# ### Initialize server

# %%
from lab1.phone_server import Server

phone_server = Server()
# Out:
# 2025-11-06 14:28:17,691 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=1524, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>

# %% [markdown]
# ### Start server

# %%
phone_server.serve()
